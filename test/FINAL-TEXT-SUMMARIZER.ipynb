# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.13/dist-packages (1.3.18)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.6.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.5.0)

# %%
from langchain.document_loaders import TextLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1352/3658283665.py in <cell line: 0>()
# ----> 1 from langchain.document_loaders import TextLoader
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.13/dist-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.6.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.12.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.7.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (0.10.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.5)

# %%
from langchain.document_loaders import TextLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6291/3800184432.py in <cell line: 0>()
# ----> 1 from langchain.document_loaders import TextLoader
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install -U langchain langchain-community
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.13/dist-packages (1.3.18)
# Collecting langchain
#   Downloading langchain-1.4.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.13/dist-packages (0.4.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.6.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain) (2.13.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.12.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.7.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (0.10.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Downloading langchain-1.4.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.18
#     Uninstalling langchain-1.3.18:
#       Successfully uninstalled langchain-1.3.18
# Successfully installed langchain-1.4.0

# %%
from langchain_community.document_loaders import TextLoader
# Out:
# /tmp/ipykernel_6291/877266886.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
from langchain_community.document_loaders import TextLoader

loader= TextLoader("nvda_news_1.txt")
df=loader.load()

df
# Out:
# /tmp/ipykernel_8944/479401490.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': 'nvda_news_1.txt'}, page_content="The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.\n\nCompany Overview\nWarning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.\n\nNVDA 30-Year Financial Data\n\nThe intrinsic value of NVDA\n\n\nNVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.\n\nCurrently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems steep. The following analysis aims to delve deeper into the company's value.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nUnderstanding the GF Value\nThe GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will likely be higher.\n\nAccording to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further strengthen this assumption.\n\nGiven that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nLink: These companies may deliver higher future returns at reduced risk.\n\nFinancial Strength of NVIDIA\nExamining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of 1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nProfitability and Growth\nConsistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.\n\nHowever, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better than 87.88% of companies in the industry.\n\nROIC vs WACC\nComparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was 20.32 while its W ...

# %%
# !pip install unstructured libmagic python-magic python-magic-bin
# Out:
# Requirement already satisfied: unstructured in /usr/local/lib/python3.13/dist-packages (0.27.5)
# Collecting libmagic
#   Downloading libmagic-1.0.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-magic in /usr/local/lib/python3.13/dist-packages (0.4.27)
# ERROR: Could not find a version that satisfies the requirement python-magic-bin (from versions: none)
# ERROR: No matching distribution found for python-magic-bin

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
# %pip install -U unstructured
# Out:
# Requirement already satisfied: unstructured in /usr/local/lib/python3.13/dist-packages (0.27.5)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.15.0)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.4.9)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.15.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.32.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (6.1.2)
# Requirement already satisfied: nh3<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.3.7)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.61.2)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.1.3)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2026.7.23)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.27 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.4.27)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.14.6)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2025.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.34.2)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.8.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.16.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.46.2)
# Requirement already satisfied: wrapt<3.0.0,>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.4.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.9.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.6.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba<1.0.0,>=0.60.0->unstructured) (0.44.0)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.5.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (2026.7.22)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.13.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (26.3)
# Requirement already satisfied: aiofiles>=25.1.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (0.28.1)
# Requirement already satisfied: pypdf>=6.9.2 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (6.18.1)
# Requirement already satisfied: pypdfium2>=5.6.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (5.13.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.28.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (4.14.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.4.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.1.2)

# %%
# %pip install -U langchain-community unstructured
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.13/dist-packages (0.4.2)
# Requirement already satisfied: unstructured in /usr/local/lib/python3.13/dist-packages (0.27.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.6.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.12.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.15.0)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.4.9)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.15.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.32.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (6.1.2)
# Requirement already satisfied: nh3<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.3.7)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.61.2)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2026.7.23)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.27 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.4.27)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.14.6)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2025.11.3)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.8.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.16.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.46.2)
# Requirement already satisfied: wrapt<3.0.0,>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.9.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.6.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba<1.0.0,>=0.60.0->unstructured) (0.44.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.4)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.5.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.7.22)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.27.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (80.10.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: aiofiles>=25.1.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: pypdf>=6.9.2 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (6.18.1)
# Requirement already satisfied: pypdfium2>=5.6.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (5.13.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community) (0.10.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.1.2)

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
loader=UnstructuredURLLoader(urls=[
    "https://www.moneycontrol.com/news/business/tata-motors-mahindra-gain-certificates-for-production-linked-payouts-11281691.html",
"https://www.moneycontrol.com/news/business/tata-motors-launches-punch-icng-price-starts-at-rs-7-1-lakh-11098751.html",
"https://www.moneycontrol.com/news/business/stocks/buy-tata-motors-target-of-rs-743-kr-choksey-11080811.html"

])

# %%
data=loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'nvda_news_1.txt'}, page_content="The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.\n\nCompany Overview\nWarning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.\n\nNVDA 30-Year Financial Data\n\nThe intrinsic value of NVDA\n\n\nNVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.\n\nCurrently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems steep. The following analysis aims to delve deeper into the company's value.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nUnderstanding the GF Value\nThe GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will likely be higher.\n\nAccording to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further strengthen this assumption.\n\nGiven that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nLink: These companies may deliver higher future returns at reduced risk.\n\nFinancial Strength of NVIDIA\nExamining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of 1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nProfitability and Growth\nConsistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.\n\nHowever, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better than 87.88% of companies in the industry.\n\nROIC vs WACC\nComparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was 20.32 while its W ...

# %%
#text splitting

# %%
# !pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.13/dist-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.6.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.11.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.7.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)

# %%
# !pip install -U langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in /usr/local/lib/python3.13/dist-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /usr/local/lib/python3.13/dist-packages (from langchain-text-splitters) (1.6.1)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.4)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
r_splitter=RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n" , " "],
    chunk_size=200,
    chunk_overlap=0
)

# %%
type(df)
# Out:
# list

# %%
chunks = []

for item in data:
    chunks.extend(r_splitter.split_documents(item))

len(chunks)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8944/3784284986.py in <cell line: 0>()
#       2
#       3 for item in data:
# ----> 4     chunks.extend(r_splitter.split_documents(item))
#       5
#       6 len(chunks)
#
# /usr/local/lib/python3.13/dist-packages/langchain_text_splitters/base.py in split_documents(self, documents)
#     140         texts, metadatas = [], []
#     141         for doc in documents:
# --> 142             texts.append(doc.page_content)
#     143             metadatas.append(doc.metadata)
#     144         return self.create_documents(texts, metadatas=metadatas)
#
# AttributeError: 'tuple' object has no attribute 'page_content'

# %%
chunks=r_splitter.split_documents(df)
len(chunks)
# Out:
# 33

# %%
for i in chunks:
  print(len(i.page_content))
# Out:
# 200
# 194
# 23
# 162
# 194
# 197
# 109
# 197
# 76
# 184
# 198
# 198
# 17
# 191
# 27
# 140
# 157
# 72
# 28
# 195
# 171
# 182
# 198
# 85
# 197
# 41
# 12
# 196
# 99
# 168
# 188
# 105
# 181

# %%
for i in chunks:
  print(i)
# Out:
# page_content='The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly' metadata={'source': 'nvda_news_1.txt'}
# page_content='overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this' metadata={'source': 'nvda_news_1.txt'}
# page_content='comprehensive analysis.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Company Overview
# Warning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.
#
# NVDA 30-Year Financial Data
#
# The intrinsic value of NVDA' metadata={'source': 'nvda_news_1.txt'}
# page_content='NVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets,' metadata={'source': 'nvda_news_1.txt'}
# page_content='including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including' metadata={'source': 'nvda_news_1.txt'}
# page_content='artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Currently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems' metadata={'source': 'nvda_news_1.txt'}
# page_content='steep. The following analysis aims to delve deeper into the company's value.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Understanding the GF Value' metadata={'source': 'nvda_news_1.txt'}
# page_content='The GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the' metadata={'source': 'nvda_news_1.txt'}
# page_content='stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will' metadata={'source': 'nvda_news_1.txt'}
# page_content='likely be higher.' metadata={'source': 'nvda_news_1.txt'}
# page_content='According to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further' metadata={'source': 'nvda_news_1.txt'}
# page_content='strengthen this assumption.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Given that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis' metadata={'source': 'nvda_news_1.txt'}
# page_content='Link: These companies may deliver higher future returns at reduced risk.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Financial Strength of NVIDIA' metadata={'source': 'nvda_news_1.txt'}
# page_content='Examining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of' metadata={'source': 'nvda_news_1.txt'}
# page_content='1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Profitability and Growth' metadata={'source': 'nvda_news_1.txt'}
# page_content='Consistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating' metadata={'source': 'nvda_news_1.txt'}
# page_content='margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.' metadata={'source': 'nvda_news_1.txt'}
# page_content='However, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better' metadata={'source': 'nvda_news_1.txt'}
# page_content='than 87.88% of companies in the industry.' metadata={'source': 'nvda_news_1.txt'}
# page_content='ROIC vs WACC' metadata={'source': 'nvda_news_1.txt'}
# page_content='Comparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was' metadata={'source': 'nvda_news_1.txt'}
# page_content='20.32 while its WACC was 16.74, suggesting that the company is creating value for its shareholders.' metadata={'source': 'nvda_news_1.txt'}
# page_content='Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Is NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis
# Conclusion' metadata={'source': 'nvda_news_1.txt'}
# page_content='In conclusion, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. Despite its strong financial condition and profitability, its growth ranks lower than 52.99% of companies in the' metadata={'source': 'nvda_news_1.txt'}
# page_content='Semiconductors industry. To learn more about NVIDIA stock, you can check out its 30-Year Financials here.' metadata={'source': 'nvda_news_1.txt'}
# page_content='To find out the high quality companies that may deliver above-average returns, please check out GuruFocus High Quality Low Capex Screener.
#
# This article first appeared on GuruFocus.' metadata={'source': 'nvda_news_1.txt'}

# %%
first_split=chunks[0]
first_split
# Out:
# Document(metadata={'source': 'nvda_news_1.txt'}, page_content='The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly')

# %%
pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.13/dist-packages (6.0.1)
# Requirement already satisfied: transformers<6.0.0,>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (5.17.0)
# Requirement already satisfied: tokenizers>=0.19 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (0.23.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (1.31.0)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (2.11.0+cpu)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (2.1.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (4.16.0)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1.0->sentence-transformers) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.1.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.2->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.2->sentence-transformers) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers<6.0.0,>=5.0.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers<6.0.0,>=5.0.0->sentence-transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers<6.0.0,>=5.0.0->sentence-transformers) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence-transformers) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence-transformers) (0.1.2)

# %%
from huggingface_hub import login

login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>5HY0-O9RI</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8944/2270011752.py in <cell line: 0>()
#       1 from huggingface_hub import login
#       2
# ----> 3 login()
#
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/_login.py in login(token, add_to_git_credential, skip_if_logged_in)
#     113         )
#     114     if is_notebook():
# --> 115         notebook_login(skip_if_logged_in=skip_if_logged_in)
#     116     else:
#     117         interpreter_login(skip_if_logged_in=skip_if_logged_in)
#
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/_login.py in notebook_login(skip_if_logged_in)
#     376     display(HTML("<center><i>Waiting for authorization...</i></center>"))
#     377     try:
# --> 378         response = poll_device_token(device_info)
#     379     except DeviceCodeError as e:
#     380         display(HTML(f"<center><b style='color: red;'>Login failed: {html.escape(str(e))}</b></center>"))
#
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_oauth_device.py in poll_device_token(device_info, on_pending)
#     148                     )
#     149
# --> 150         time.sleep(interval)
#     151
#     152     raise DeviceCodeError("Device code expired (timeout). Please try again.", error_code=OAuthErrorCode.EXPIRED_TOKEN)
#
# KeyboardInterrupt:

# %%
# !pip install -U sentence-transformers transformers huggingface_hub
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.13/dist-packages (6.0.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.13/dist-packages (5.17.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.13/dist-packages (1.31.0)
# Requirement already satisfied: tokenizers>=0.19 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (0.23.1)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (2.11.0+cpu)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (2.1.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (4.16.0)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from transformers) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1.0->sentence-transformers) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.2->sentence-transformers) (3.1.6)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers) (0.0.5)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.1.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers) (2.21.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.2->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.2->sentence-transformers) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
import sentence_transformers
import huggingface_hub
import transformers

print("sentence-transformers:", sentence_transformers.__version__)
print("huggingface-hub:", huggingface_hub.__version__)
print("transformers:", transformers.__version__)
# Out:
# sentence-transformers: 6.0.1
# huggingface-hub: 1.31.0
# transformers: 5.17.0

# %%
from sentence_transformers import SentenceTransformer

encoder = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

texts = [chunk.page_content for chunk in chunks]

vectors = encoder.encode(texts)

print(vectors.shape)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# (33, 384)

# %%
vectors
# Out:
# array([[ 0.01213212,  0.04138049, -0.01303827, ..., -0.1434358 ,
#          0.03958008,  0.02010916],
#        [-0.02355827,  0.00036534, -0.0543414 , ..., -0.14552884,
#         -0.00870825,  0.07526036],
#        [ 0.00431114,  0.02234809,  0.03590514, ..., -0.0248266 ,
#          0.05890223,  0.00207635],
#        ...,
#        [ 0.00029819, -0.08387236, -0.01246105, ..., -0.15560722,
#          0.04677229,  0.09304617],
#        [-0.00197264, -0.04976522, -0.02915698, ..., -0.09309749,
#          0.10168338,  0.10852072],
#        [-0.04916925, -0.10959   ,  0.01308912, ..., -0.11218736,
#          0.00570663,  0.10663083]], dtype=float32)

# %%
dim=vectors[1]

# %%
dim
# Out:
# array([-2.35582665e-02,  3.65340384e-04, -5.43414019e-02, -1.39293419e-02,
#        -1.24649354e-03, -5.21280766e-02, -2.79536545e-02,  1.02162726e-01,
#        -1.52973775e-02,  3.46231945e-02, -1.35716558e-01,  2.32234917e-04,
#        -1.17751434e-02, -2.07117032e-02, -1.42296441e-02,  6.39179163e-03,
#         7.31972009e-02, -4.50677499e-02, -4.40420322e-02,  7.61464005e-03,
#        -1.80041694e-04, -3.37197669e-02,  5.40150469e-03,  2.07371898e-02,
#         3.00587937e-02, -7.24573527e-03, -2.36202739e-02, -3.65162478e-03,
#         2.07437854e-02, -3.02702971e-02, -2.86396742e-02,  5.05619422e-02,
#         4.64321710e-02,  2.05691960e-02,  4.00319137e-02, -1.41795222e-02,
#         3.42256506e-03, -4.56301123e-02, -6.76305741e-02, -3.69567499e-02,
#         5.47198346e-03, -1.89670417e-02, -4.05139588e-02,  2.10557282e-02,
#         3.18636000e-02, -4.47129570e-02, -1.22872973e-02,  1.10157644e-02,
#         4.01026849e-03,  4.68382835e-02, -2.27454938e-02, -2.51096506e-02,
#        -8.32825527e-03, -4.82548885e-02, -4.16268222e-02,  4.49573882e-02,
#        -3.26203965e-02, -1.34103492e-01,  1.00003723e-02, -2.65004635e-02,
#         1.09048091e-01, -5.82790002e-02,  1.72816515e-02,  7.42886513e-02,
#         6.62195012e-02, -4.90822122e-02,  3.29040736e-02, -4.10214849e-02,
#        -6.80290535e-02,  2.66057942e-02,  5.01673371e-02, -2.50377879e-02,
#        -7.85188563e-03, -6.56937212e-02, -6.79533482e-02,  1.11332228e-02,
#        -2.68975999e-02, -3.97562161e-02,  5.66388890e-02, -2.31455918e-03,
#         6.68060929e-02,  4.42377012e-03,  1.34517103e-02, -3.27008627e-02,
#         8.53413641e-02, -2.49374323e-02,  1.02723964e-01, -4.06168960e-02,
#         4.92252409e-02, -4.96440986e-03,  1.27144372e-02,  6.37912611e-03,
#         5.17606214e-02,  4.00110334e-02, -2.23316010e-02,  2.16937028e-02,
#        -4.26130891e-02, -8.18578824e-02, -1.76301859e-02,  4.26621782e-03,
#         3.61434394e-03,  1.00550451e-03,  3.07769310e-02,  8.81290250e-03,
#        -9.88946203e-03, -4.32843663e-04, -3.34509015e-02,  4.65799160e-02,
#        -3.69346421e-03, -2.12049745e-02, -2.48013139e-02,  3.91738452e-02,
#        -2.84178313e-02, -1.63683982e-03,  1.48169091e-02,  8.22651014e-02,
#        -7.39218593e-02,  1.08422609e-02,  1.43474769e-02, -1.23804631e-02,
#         1.39991343e-02, -7.09810406e-02, -3.15298364e-02,  1.13894390e-02,
#        -4.17731032e-02, -1.53034758e-02, -5.74347051e-03, -2.13546971e-33,
#        -3.38451006e-02, -4.30154093e-02,  1.87539421e-02, -9.57957059e-02,
#        -1.39756594e-02,  1.15685239e-01,  6.95236353e-03,  2.11905893e-02,
#        -1.68025903e-02, -2.33205855e-02, -6.04795618e-03,  8.06754604e-02,
#        -4.03209142e-02, -4.70038597e-03,  2.24291682e-02, -3.50133143e-02,
#        -6.39896318e-02,  5.97590283e-02,  8.02081525e-02,  8.39812383e-02,
#         9.95245427e-02,  3.55702173e-03,  1.49869015e-02, -6.78264443e-03,
#         2.22964138e-02, -1.18476646e-02, -1.04733177e-01,  1.18451212e-02,
#        -6.46749558e-03,  2.48822868e-02,  6.76110610e-02, -6.47046044e-02,
#        -3.80137712e-02, -4.40458767e-02, -3.15681137e-02,  1.17747495e-02,
#        -2.75103226e-02,  4.28430885e-02, -8.24112631e-03,  7.52289146e-02,
#        -6.37265220e-02,  6.51807562e-02, -7.16785416e-02, -8.49043205e-02,
#        -7.95945749e-02,  3.75741497e-02,  7.66211841e-03, -7.80160725e-02,
#        -6.69765845e-02,  1.16559444e-02, -9.81309265e-02,  9.25336964e-03,
#        -1.05289049e-01, -3.05889025e-02, -1.67343225e-02,  6.94040861e-03,
#         2.28408128e-02, -1.59558863e-03, -1.18583050e-02,  2.06075497e-02,
#        -7.58160427e-02, -6.83946759e-02, -1.18959825e-02, -8.37472007e-02,
#        -1.12413079e-01,  9.45090055e-02,  8.48345086e-02,  1.68824587e-02,
#        -5.00786118e-02,  1.55743146e-02, -3.04028168e-02,  1.49488235e-02,
#        -4.85843010e-02, -2.13779067e-03,  2.49910820e-02, -2.21172981e-02,
#        -6.72263429e-02,  1.78404581e-02,  4.41653728e-02,  3.62822153e-02,
#        -5.06483279e-02,  2.18354873e-02,  1.58823580e-02, -1.00804446e-03,
#         1.03304656e-02,  3.85181443e-03, -2.53598299e-02,  3.60346213e-02,
#        -3.13597806e-02, -4.99737747e-02, -9.80167612e-02,  5.41183241e-02,
#         1.68863367e-02, -3.28634046e-02,  2.72002313e-02, -5.13285118e-34,
#         3.43412496e-02,  2.06890386e-02,  3.48327607e-02,  1.19273208e-01,
#        -4.85703908e-02, -3.80341560e-02, -8.91910270e-02,  2.42455248e-02,
#        -5.50616905e-02, -1.54363587e-02,  5.94399078e-03,  1.28964186e-01,
#         2.04258971e-02,  5.78141063e-02, -4.28675935e-02, -7.49799907e-02,
#         3.49707110e-03, -5.99085540e-02, -2.23703440e-02, -1.27164885e-01,
#        -2.70679984e-02,  4.32836264e-02, -9.96307004e-03,  6.29268028e-03,
#        -2.85160895e-02,  7.16609731e-02, -3.18936966e-02, -8.68753716e-02,
#         8.99622291e-02, -4.12085690e-02,  3.51438187e-02,  2.93469848e-03,
#         5.38701266e-02,  6.13393150e-02,  9.35364664e-02,  3.48615497e-02,
#         1.02824107e-01, -3.18927690e-02,  1.86327640e-02,  3.94187793e-02,
#         1.08705603e-01,  5.78723699e-02,  3.63498777e-02, -1.07270777e-02,
#         5.64711653e-02,  1.97506156e-02, -3.03753018e-02,  5.47522446e-03,
#         1.14654973e-01, -2.04375256e-02,  1.67431589e-02, -4.38988507e-02,
#         4.21074145e-02,  1.06784798e-01, -7.21028969e-02,  1.49707990e-02,
#         4.19540592e-02,  7.66817182e-02,  5.51624298e-02, -7.93712139e-02,
#         3.86495069e-02,  1.04762912e-01, -8.80818292e-02,  5.78556135e-02,
#        -3.07081528e-02, -3.12816282e-03,  9.43763833e-03, -1.58348568e-02,
#         6.19391203e-02, -8.83173570e-02, -2.40241662e-02, -7.89506361e-02,
#        -3.13433595e-02, -3.73989269e-02, -1.02306984e-01,  6.28499463e-02,
#         1.64841507e-02, -6.20333776e-02,  6.86502084e-02, -9.10288841e-03,
#        -1.91999432e-02, -5.77292182e-02,  4.30211537e-02, -7.50474958e-03,
#        -2.21157838e-02, -3.33228782e-02,  9.02685598e-02, -6.98919743e-02,
#        -3.52988206e-03,  3.36934477e-02, -8.05111900e-02,  4.52985615e-03,
#        -1.00798242e-01, -3.21758948e-02, -5.02176918e-02, -2.87797697e-08,
#         4.17549647e-02, -7.44070709e-02,  1.87178142e-02,  9.95106995e-02,
#         5.96593656e-02, -8.06154087e-02, -1.49482107e-02,  1.83561910e-02,
#         2.77575552e-02,  8.17574635e-02,  9.66053084e-02, -8.16041529e-02,
#        -6.37838468e-02,  3.58915050e-03, -4.35381122e-02,  3.65511924e-02,
#        -2.26751398e-02,  1.04788378e-01,  5.00573888e-02,  3.73453088e-02,
#        -1.86408944e-02,  5.71858846e-02,  3.49951303e-03, -5.48023954e-02,
#        -1.95544679e-02,  2.45933440e-02,  4.09334973e-02, -4.06743921e-02,
#         6.55854866e-02, -2.70147119e-02, -5.86631987e-03,  6.29192144e-02,
#         1.04084536e-01, -7.87828024e-03,  2.98834424e-02, -3.09257340e-02,
#         6.61184862e-02,  2.32938733e-02,  1.08709708e-01,  4.20354940e-02,
#         2.96635125e-02,  1.73331611e-02,  4.18605097e-03, -9.50370543e-03,
#         4.81615625e-02, -1.99414901e-02, -2.28075664e-02, -2.55396143e-02,
#        -6.07483611e-02, -3.09016481e-02, -4.15355600e-02,  3.51975076e-02,
#         1.44881019e-02,  5.19789457e-02, -8.58631954e-02, -6.19758060e-03,
#        -7.45723918e-02,  7.09027946e-02, -1.05055511e-01,  1.32108747e-03,
#         3.55051719e-02, -1.45528838e-01, -8.70824791e-03,  7.52603561e-02],
#       dtype=float32)

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.13/dist-packages (1.15.0)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.13/dist-packages (from faiss-cpu) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from faiss-cpu) (26.3)

# %%
dim = vectors.shape[1]

print("Embedding shape:", vectors.shape)
print("Dimension:", dim)

index = faiss.IndexFlatL2(dim)

index.add(vectors)

print("FAISS vectors:", index.ntotal)
# Out:
# Embedding shape: (33, 384)
# Dimension: 384
# FAISS vectors: 33

# %%
index.add(vectors)

# %%
search_query="NVIDIA Stock"
vec=encoder.encode(search_query)
vec.shape
# Out:
# (384,)

# %%
import numpy as np
svec=np.array(vec).reshape(1,-1)
svec.shape
# Out:
# (1, 384)

# %%
svec
# Out:
# array([[-2.40351167e-02, -4.07368131e-03, -4.94529195e-02,
#          2.95253620e-02, -1.96885355e-02,  5.16092451e-03,
#          7.49862799e-03, -8.93013272e-03,  5.09015583e-02,
#         -2.06747930e-02, -1.41357109e-02,  4.76275980e-02,
#         -1.01354428e-01, -1.53385028e-02, -3.79299372e-02,
#          7.27395480e-03,  9.15150903e-03, -3.76040526e-02,
#          2.77849170e-03, -2.90839747e-02, -8.21019933e-02,
#         -5.68654798e-02, -1.10413209e-02,  2.18176451e-02,
#         -3.70589813e-04,  4.27302122e-02,  4.03065095e-03,
#          6.12045750e-02,  1.62698999e-02, -9.59792733e-02,
#         -3.45955193e-02,  1.15531888e-02,  7.55476654e-02,
#          3.98997366e-02, -2.34439094e-02, -6.73590973e-02,
#          7.37263355e-03, -4.91461083e-02,  5.60867228e-03,
#         -2.27684714e-02, -1.44637413e-02, -2.83176516e-04,
#         -2.60320958e-02,  4.16476130e-02,  5.85992076e-02,
#         -2.04411764e-02,  2.13349867e-03,  3.06599755e-02,
#          1.28266692e-01, -2.41123475e-02, -2.52934322e-02,
#         -5.13413437e-02, -1.79572087e-02, -2.18031928e-02,
#         -4.53187339e-02,  4.30859476e-02, -6.79867789e-02,
#         -6.60481378e-02,  7.67999589e-02, -3.12294140e-02,
#          1.45390719e-01, -4.37551513e-02,  1.14908908e-03,
#          9.11610723e-02,  8.30438510e-02, -3.30982334e-03,
#          5.38115669e-03,  4.60544694e-03, -9.10499657e-04,
#         -1.07634757e-02,  5.33669665e-02,  1.47606162e-02,
#         -5.51697724e-02, -2.52350233e-02, -1.35221958e-01,
#         -8.43722373e-03,  3.78154777e-02, -1.73525363e-02,
#          6.92635253e-02,  1.01295738e-02, -3.14583369e-02,
#         -2.99570430e-03,  4.51264791e-02, -1.35018770e-02,
#          4.34568226e-02,  8.68105330e-03,  1.11223996e-01,
#          7.07812011e-02,  3.16506997e-02, -5.74030541e-02,
#         -6.57802075e-02, -4.03776066e-03,  8.07396844e-02,
#          3.88353691e-02, -8.60634670e-02,  3.20287533e-02,
#          7.34077301e-03, -7.04024136e-02, -3.87499966e-02,
#          6.06108569e-02,  6.79979995e-02,  1.14658484e-02,
#          2.47410275e-02,  8.09598193e-02, -4.33410928e-02,
#          2.58437712e-02, -6.40524551e-02,  3.32901403e-02,
#         -2.28241459e-02,  2.63308007e-02, -8.50687474e-02,
#          8.16484615e-02, -1.17552765e-01,  1.35592222e-02,
#         -1.02227367e-01,  4.11778130e-02, -9.18031633e-02,
#         -1.36431111e-02,  1.47866784e-02,  7.89056905e-03,
#         -4.94099269e-03, -2.06727218e-02, -2.90478077e-02,
#         -1.49835115e-02, -1.54460231e-02,  2.36236434e-02,
#          7.32345879e-03,  4.52378624e-34,  5.75835407e-02,
#         -2.97168195e-02, -1.11835618e-02, -2.25504823e-02,
#          3.28046493e-02,  1.13040902e-01,  8.31840634e-02,
#          1.76233780e-02, -3.59753072e-02,  3.09418645e-02,
#         -8.28129798e-02,  3.93872000e-02, -5.40960804e-02,
#          4.72689644e-02, -1.71301626e-02, -8.09112117e-02,
#         -1.60234459e-02,  1.74446311e-02,  4.50613275e-02,
#          1.05818799e-02,  3.32880542e-02,  5.78933023e-02,
#         -3.80821414e-02,  1.67293139e-02, -7.91401509e-03,
#         -3.64913493e-02, -6.15916811e-02,  3.34880111e-04,
#          3.20888422e-02,  3.40732671e-02,  8.56376663e-02,
#         -4.31762524e-02, -3.29694375e-02, -4.58068550e-02,
#          3.21081392e-02, -4.30233367e-02, -5.62399887e-02,
#          3.59829189e-03,  4.71930057e-02,  6.75196946e-02,
#          2.93134265e-02,  1.06219001e-01, -7.93561563e-02,
#         -9.96177047e-02, -6.86881989e-02,  5.94983175e-02,
#         -1.95390247e-02, -4.87957001e-02, -5.68701625e-02,
#          3.64994295e-02, -8.58336166e-02,  4.50374782e-02,
#         -4.34451662e-02, -4.41881604e-02,  3.01161893e-02,
#         -3.21373381e-02,  1.23150954e-02, -1.42407827e-02,
#          9.53488331e-03, -6.30654767e-02, -4.11951132e-02,
#         -1.42351370e-02, -7.31141400e-03, -3.16854790e-02,
#         -6.87798113e-02,  5.80545776e-02,  5.51944040e-02,
#          3.57526802e-02, -1.06461518e-01,  1.48234041e-02,
#         -1.66017581e-02,  1.46943694e-02,  5.34880050e-02,
#         -2.45131534e-02,  5.72944656e-02, -3.95289734e-02,
#         -1.17896326e-01,  9.49413143e-03, -2.26661190e-02,
#         -2.57843453e-02, -3.33491783e-03,  4.94704209e-03,
#          9.06442944e-03,  6.40832335e-02, -8.57274234e-03,
#          7.87826348e-03, -2.46433634e-02,  2.12843996e-02,
#         -5.72923571e-04, -4.38279398e-02, -1.31009862e-01,
#          9.55787487e-03,  3.96065600e-02,  1.34811290e-02,
#          4.07324880e-02, -6.07412829e-34,  3.38924602e-02,
#         -4.62974906e-02,  7.59177422e-03,  9.31899715e-03,
#         -2.59191822e-02,  1.62527300e-02,  2.80065089e-02,
#          2.18148101e-02, -1.93788484e-02,  5.93035780e-02,
#          7.14911744e-02,  8.75930414e-02,  3.59185897e-02,
#          4.88913245e-02, -5.10573685e-02, -4.13295589e-02,
#          2.02159416e-02,  2.15525627e-02, -1.92627497e-02,
#         -1.43987909e-01, -5.53537235e-02, -5.19086979e-02,
#         -1.19449245e-02,  1.00576831e-02,  5.07609732e-02,
#          3.83860953e-02,  7.29091614e-02, -1.05099231e-02,
#         -1.14386138e-02, -2.50878502e-02, -5.31903887e-03,
#         -1.64457336e-02,  5.87974070e-03,  1.06672101e-01,
#          4.11742330e-02, -1.35200415e-02,  4.27040234e-02,
#          1.98967848e-02,  6.53515430e-03, -8.55033100e-03,
#          7.48117715e-02,  6.24959953e-02,  1.38570383e-01,
#          6.70894384e-02,  3.83936688e-02,  3.47243389e-03,
#          4.73569818e-02, -1.56063074e-02,  1.13847092e-01,
#          2.21829899e-02, -6.75264150e-02,  9.18873120e-04,
#          5.22510819e-02,  8.14867914e-02, -3.01012583e-02,
#          6.53709248e-02,  2.05534399e-02,  9.05089825e-02,
#          1.06194988e-03, -5.17160632e-02,  1.42829744e-02,
#          6.35598153e-02, -8.08913857e-02, -4.41043414e-02,
#          8.62019509e-03, -4.72081127e-03, -6.58892542e-02,
#         -8.87659844e-03,  7.06931651e-02, -3.96800935e-02,
#          2.69377790e-02, -6.67138472e-02,  2.74688490e-02,
#         -3.18497941e-02, -8.84862319e-02, -1.18065747e-02,
#          4.71474156e-02, -7.30144009e-02,  6.81528002e-02,
#          2.63907369e-02,  4.40185070e-02, -8.78177434e-02,
#          6.27956465e-02,  6.35146201e-02, -2.46429648e-02,
#          2.20576804e-02,  7.95991272e-02, -6.06634729e-02,
#          3.35855819e-02, -1.45624625e-02, -4.26606983e-02,
#          1.18177617e-02, -2.70271916e-02,  8.22922494e-03,
#         -4.10934798e-02, -1.41688083e-08,  2.64836997e-02,
#         -6.66262805e-02,  5.57991788e-02,  7.35821724e-02,
#          8.47289190e-02, -5.00938147e-02, -9.30780545e-03,
#         -2.60035582e-02,  2.56206337e-02,  3.60721499e-02,
#          7.45582804e-02, -4.83945943e-02, -1.01558305e-01,
#          1.03626801e-02, -3.61311510e-02, -7.18652830e-03,
#         -7.52983056e-03,  5.19893356e-02,  1.16069410e-02,
#          2.19438467e-02, -2.18851641e-02,  3.52491550e-02,
#          1.14373498e-01,  1.08980425e-02, -6.53461963e-02,
#         -1.91645026e-02,  1.12215869e-01, -4.19225059e-02,
#          7.18535110e-02, -1.48777375e-02, -2.73663830e-02,
#          7.97203034e-02,  1.30929828e-01, -3.08839623e-02,
#         -2.56520845e-02, -2.52427943e-02,  5.07434905e-02,
#          4.82383594e-02,  6.08480573e-02, -5.86152263e-02,
#          6.56917132e-03, -5.18235043e-02,  3.73484306e-02,
#         -4.20418195e-02,  3.92343253e-02,  1.61692053e-02,
#         -4.86381240e-02, -8.47491547e-02, -1.29958708e-02,
#         -6.11349605e-02, -3.45646739e-02, -3.55224242e-03,
#         -3.77091840e-02,  9.40977558e-02, -7.37484321e-02,
#          2.51903757e-02, -6.35280013e-02, -4.78286296e-03,
#         -9.76397917e-02, -4.14960943e-02, -3.02433763e-02,
#         -1.24010675e-01,  4.22080308e-02,  3.97706702e-02]], dtype=float32)

# %%
dis, I=index.search(svec,k=2)
dis
# Out:
# array([[0.5959543, 0.5959543]], dtype=float32)

# %%
print(dis)
print(I)
# Out:
# [[0.5959543 0.5959543]]
# [[29 62]]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_20002/2758231444.py in <cell line: 0>()
# ----> 1 results = [df[i] for i in I[0]]
#
# IndexError: list index out of range

# %%
print("Number of df items:", len(df))
print("FAISS indices:", I)
print("First row:", I[0])
# Out:
# Number of df items: 1
# FAISS indices: [[29 62]]
# First row: [29 62]

# %%
print("df items:", len(df))
print("vectors shape:", vectors.shape)
print("FAISS vectors:", index.ntotal)
print("FAISS indices:", I)
# Out:
# df items: 1
# vectors shape: (33, 384)
# FAISS vectors: 66
# FAISS indices: [[29 62]]

# %%
print("Number of vectors:", len(vectors))
print("FAISS index size:", index.ntotal)
# Out:
# Number of vectors: 33
# FAISS index size: 66

# %%
results = [chunks[i] for i in I[0]]
for result in results:
    print(result.page_content)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_8944/1545710294.py in <cell line: 0>()
# ----> 1 results = [chunks[i] for i in I[0]]
#       2 for result in results:
#       3     print(result.page_content)
#
# IndexError: list index out of range

# %%
pip install langchain-openai Collecting langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.6.2-py3-none-any.whl.metadata (3.4 kB)
# ERROR: Could not find a version that satisfies the requirement Collecting (from versions: none)
# ERROR: No matching distribution found for Collecting

# %%
# !pip install -U langchain-openai
# Out:
# Collecting langchain-openai
#   Using cached langchain_openai-1.6.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: certifi>=2024.6.2 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (2026.7.22)
# Collecting langchain-core<2.0.0,>=1.6.2 (from langchain-openai)
#   Downloading langchain_core-1.6.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (2.54.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.13.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.17.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.34.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=3.5.0->openai<4.0.0,>=2.45.0->langchain-openai) (3.19)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.2->langchain-openai) (3.1.1)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.2->langchain-openai) (0.10.4)
# Downloading langchain_openai-1.6.2-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 1.1 MB/s eta 0:00:00
# Downloading langchain_core-1.6.3-py3-none-any.whl (571 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.8/571.8 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain-openai
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.6.1
#     Uninstalling langchain-core-1.6.1:
#       Successfully uninstalled langchain-core-1.6.1
# Successfully installed langchain-core-1.6.3 langchain-openai-1.6.2

# %%
import os
import streamlit as st
import pickle
import time
from langchain import OpenAI
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env (especially openai api key)

st.title("RockyBot: News Research Tool 📈")
st.sidebar.title("News Article URLs")

urls = []
for i in range(3):
    url = st.sidebar.text_input(f"URL {i+1}")
    urls.append(url)

process_url_clicked = st.sidebar.button("Process URLs")
file_path = "faiss_store_openai.pkl"

main_placeholder = st.empty()
llm = OpenAI(temperature=0.9, max_tokens=500)

if process_url_clicked:
    # load data
    loader = UnstructuredURLLoader(urls=urls)
    main_placeholder.text("Data Loading...Started...✅✅✅")
    data = loader.load()
    # split data
    text_splitter = RecursiveCharacterTextSplitter(
        separators=['\n\n', '\n', '.', ','],
        chunk_size=1000
    )
    main_placeholder.text("Text Splitter...Started...✅✅✅")
    docs = text_splitter.split_documents(data)
    # create embeddings and save it to FAISS index
    embeddings = OpenAIEmbeddings()
    vectorstore_openai = FAISS.from_documents(docs, embeddings)
    main_placeholder.text("Embedding Vector Started Building...✅✅✅")
    time.sleep(2)

    # Save the FAISS index to a pickle file
    with open(file_path, "wb") as f:
        pickle.dump(vectorstore_openai, f)

query = main_placeholder.text_input("Question: ")
if query:
    if os.path.exists(file_path):
        with open(file_path, "rb") as f:
            vectorstore = pickle.load(f)
            chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vectorstore.as_retriever())
            result = chain({"question": query}, return_only_outputs=True)
            # result will be a dictionary of this format --> {"answer": "", "sources": [] }
            st.header("Answer")
            st.write(result["answer"])

            # Display sources, if available
            sources = result.get("sources", "")
            if sources:
                st.subheader("Sources:")
                sources_list = sources.split("\n")  # Split the sources by newline
                for source in sources_list:
                    st.write(source)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6266/3823646972.py in <cell line: 0>()
#       1 import os
# ----> 2 import streamlit as st
#       3 import pickle
#       4 import time
#       5 from langchain import OpenAI
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 69.6 MB/s eta 0:00:00

# %%
import os
import streamlit as st
import pickle
import time
from langchain import OpenAI
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env (especially openai api key)

st.title("RockyBot: News Research Tool 📈")
st.sidebar.title("News Article URLs")

urls = []
for i in range(3):
    url = st.sidebar.text_input(f"URL {i+1}")
    urls.append(url)

process_url_clicked = st.sidebar.button("Process URLs")
file_path = "faiss_store_openai.pkl"

main_placeholder = st.empty()
llm = OpenAI(temperature=0.9, max_tokens=500)

if process_url_clicked:
    # load data
    loader = UnstructuredURLLoader(urls=urls)
    main_placeholder.text("Data Loading...Started...✅✅✅")
    data = loader.load()
    # split data
    text_splitter = RecursiveCharacterTextSplitter(
        separators=['\n\n', '\n', '.', ','],
        chunk_size=1000
    )
    main_placeholder.text("Text Splitter...Started...✅✅✅")
    docs = text_splitter.split_documents(data)
    # create embeddings and save it to FAISS index
    embeddings = OpenAIEmbeddings()
    vectorstore_openai = FAISS.from_documents(docs, embeddings)
    main_placeholder.text("Embedding Vector Started Building...✅✅✅")
    time.sleep(2)

    # Save the FAISS index to a pickle file
    with open(file_path, "wb") as f:
        pickle.dump(vectorstore_openai, f)

query = main_placeholder.text_input("Question: ")
if query:
    if os.path.exists(file_path):
        with open(file_path, "rb") as f:
            vectorstore = pickle.load(f)
            chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vectorstore.as_retriever())
            result = chain({"question": query}, return_only_outputs=True)
            # result will be a dictionary of this format --> {"answer": "", "sources": [] }
            st.header("Answer")
            st.write(result["answer"])

            # Display sources, if available
            sources = result.get("sources", "")
            if sources:
                st.subheader("Sources:")
                sources_list = sources.split("\n")  # Split the sources by newline
                for source in sources_list:
                    st.write(source)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_6266/3823646972.py in <cell line: 0>()
#       3 import pickle
#       4 import time
# ----> 5 from langchain import OpenAI
#       6 from langchain.chains import RetrievalQAWithSourcesChain
#       7 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ImportError: cannot import name 'OpenAI' from 'langchain' (/usr/local/lib/python3.13/dist-packages/langchain/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q streamlit sentence-transformers faiss-cpu transformers torch \
    langchain langchain-community beautifulsoup4 requests pyngrok

# %%
from google.colab import userdata

api_key = userdata.get("my_key")

print("API key loaded:", bool(api_key))
# Out:
# API key loaded: True

# %%
import os
import streamlit as st
import pickle
import time
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env (especially openai api key)

st.title("UrBot: News Research Tool 📈")
st.sidebar.title("News Article URLs")

urls = []
for i in range(3):
    url = st.sidebar.text_input(f"URL {i+1}")
    urls.append(url)

process_url_clicked = st.sidebar.button("Process URLs")
file_path = "faiss_store_openai.pkl"

main_placeholder = st.empty()
llm = llm = ChatOpenAI(
    model="gpt-5.5",
    temperature=0,
    max_tokens=500
)

if process_url_clicked:
    # load data
    loader = UnstructuredURLLoader(urls=urls)
    main_placeholder.text("Data Loading...Started...✅✅✅")
    data = loader.load()
    # split data
    text_splitter = RecursiveCharacterTextSplitter(
        separators=['\n\n', '\n', '.', ','],
        chunk_size=1000
    )
    main_placeholder.text("Text Splitter...Started...✅✅✅")
    docs = text_splitter.split_documents(data)
    # create embeddings and save it to FAISS index
    embeddings = OpenAIEmbeddings()
    vectorstore_openai = FAISS.from_documents(docs, embeddings)
    main_placeholder.text("Embedding Vector Started Building...✅✅✅")
    time.sleep(2)

    # Save the FAISS index to a pickle file
    with open(file_path, "wb") as f:
        pickle.dump(vectorstore_openai, f)

query = main_placeholder.text_input("Question: ")
if query:
    if os.path.exists(file_path):
        with open(file_path, "rb") as f:
            vectorstore = pickle.load(f)
            chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vectorstore.as_retriever())
            result = chain({"question": query}, return_only_outputs=True)
            # result will be a dictionary of this format --> {"answer": "", "sources": [] }
            st.header("Answer")
            st.write(result["answer"])

            # Display sources, if available
            sources = result.get("sources", "")
            if sources:
                st.subheader("Sources:")
                sources_list = sources.split("\n")  # Split the sources by newline
                for source in sources_list:
                    st.write(source)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6266/1057318507.py in <cell line: 0>()
#       4 import time
#       5 from langchain_openai import ChatOpenAI
# ----> 6 from langchain.chains import RetrievalQAWithSourcesChain
#       7 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       8 from langchain.document_loaders import UnstructuredURLLoader
#
# ModuleNotFoundError: No module named 'langchain.chains'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q langchain-openai langchain-community langchain-text-splitters unstructured

# %%
import os
import streamlit as st
import pickle
import time
from langchain_openai import OpenAI
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env (especially openai api key)

st.title("RockyBot: News Research Tool 📈")
st.sidebar.title("News Article URLs")

urls = []
for i in range(3):
    url = st.sidebar.text_input(f"URL {i+1}")
    urls.append(url)

process_url_clicked = st.sidebar.button("Process URLs")
file_path = "faiss_store_openai.pkl"

main_placeholder = st.empty()
llm = OpenAI(temperature=0.9, max_tokens=500)

if process_url_clicked:
    # load data
    loader = UnstructuredURLLoader(urls=urls)
    main_placeholder.text("Data Loading...Started...✅✅✅")
    data = loader.load()
    # split data
    text_splitter = RecursiveCharacterTextSplitter(
        separators=['\n\n', '\n', '.', ','],
        chunk_size=1000
    )
    main_placeholder.text("Text Splitter...Started...✅✅✅")
    docs = text_splitter.split_documents(data)
    # create embeddings and save it to FAISS index
    embeddings = OpenAIEmbeddings()
    vectorstore_openai = FAISS.from_documents(docs, embeddings)
    main_placeholder.text("Embedding Vector Started Building...✅✅✅")
    time.sleep(2)

    # Save the FAISS index to a pickle file
    with open(file_path, "wb") as f:
        pickle.dump(vectorstore_openai, f)

query = main_placeholder.text_input("Question: ")
if query:
    if os.path.exists(file_path):
        with open(file_path, "rb") as f:
            vectorstore = pickle.load(f)
            chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vectorstore.as_retriever())
            result = chain({"question": query}, return_only_outputs=True)
            # result will be a dictionary of this format --> {"answer": "", "sources": [] }
            st.header("Answer")
            st.write(result["answer"])

            # Display sources, if available
            sources = result.get("sources", "")
            if sources:
                st.subheader("Sources:")
                sources_list = sources.split("\n")  # Split the sources by newline
                for source in sources_list:
                    st.write(source)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6266/2564385641.py in <cell line: 0>()
#       4 import time
#       5 from langchain_openai import OpenAI
# ----> 6 from langchain.chains import RetrievalQAWithSourcesChain
#       7 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       8 from langchain.document_loaders import UnstructuredURLLoader
#
# ModuleNotFoundError: No module named 'langchain.chains'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q langchain-openai

# %%
import os
import streamlit as st
import pickle
import time
import faiss

from sentence_transformers import SentenceTransformer

from langchain_openai import ChatOpenAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import UnstructuredURLLoader
from langchain_core.prompts import ChatPromptTemplate

from dotenv import load_dotenv

load_dotenv()


# --------------------------------------------------
# STREAMLIT UI
# --------------------------------------------------

st.title("RockyBot: News Research Tool 📈")
st.sidebar.title("News Article URLs")

urls = []

for i in range(3):
    url = st.sidebar.text_input(f"URL {i+1}")
    urls.append(url)

process_url_clicked = st.sidebar.button("Process URLs")

file_path = "faiss_store.pkl"

main_placeholder = st.empty()


# --------------------------------------------------
# LLM
# --------------------------------------------------

llm = ChatOpenAI(
    model="gpt-5.5",
    temperature=0,
    max_tokens=500
)


# --------------------------------------------------
# SENTENCE TRANSFORMER
# --------------------------------------------------

encoder = SentenceTransformer("all-MiniLM-L6-v2")


# --------------------------------------------------
# PROMPT
# --------------------------------------------------

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        """You are a helpful news research assistant.

Answer the question using only the provided context.

If the answer cannot be found in the context,
say that you don't know.

Context:
{context}
"""
    ),
    ("human", "{question}")
])


chain = prompt | llm


# --------------------------------------------------
# PROCESS URLS
# --------------------------------------------------

if process_url_clicked:

    # Remove empty URLs
    urls = [url for url in urls if url.strip()]

    if not urls:
        st.error("Please enter at least one URL.")
        st.stop()


    # --------------------------------------------------
    # 1. LOAD DATA
    # --------------------------------------------------

    main_placeholder.text(
        "Data Loading...Started...✅"
    )

    loader = UnstructuredURLLoader(urls=urls)

    data = loader.load()

    st.write("Documents loaded:", len(data))


    # --------------------------------------------------
    # 2. TEXT SPLITTING
    # --------------------------------------------------

    main_placeholder.text(
        "Text Splitting...Started...✅"
    )

    text_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n", ".", ","],
        chunk_size=1000,
        chunk_overlap=100
    )

    docs = text_splitter.split_documents(data)

    st.write("Number of chunks:", len(docs))


    # --------------------------------------------------
    # 3. CREATE EMBEDDINGS
    # --------------------------------------------------

    main_placeholder.text(
        "Creating Embeddings...Started...✅"
    )

    texts = [
        doc.page_content
        for doc in docs
    ]

    vectors = encoder.encode(
        texts,
        convert_to_numpy=True
    )

    st.write("Embedding shape:", vectors.shape)


    # --------------------------------------------------
    # 4. CREATE FAISS INDEX
    # --------------------------------------------------

    main_placeholder.text(
        "Building FAISS Index...Started...✅"
    )

    dimension = vectors.shape[1]

    index = faiss.IndexFlatL2(dimension)

    index.add(vectors)

    st.write("Vectors stored in FAISS:", index.ntotal)


    # --------------------------------------------------
    # 5. SAVE FAISS + DOCUMENTS
    # --------------------------------------------------

    with open(file_path, "wb") as f:

        pickle.dump(
            {
                "index": index,
                "docs": docs
            },
            f
        )


    main_placeholder.text(
        "Processing Complete! ✅"
    )

    time.sleep(1)

    main_placeholder.empty()


# --------------------------------------------------
# QUESTION
# --------------------------------------------------

query = st.text_input("Question:")


if query:

    if os.path.exists(file_path):


        # LOAD FAISS + DOCUMENTS


        with open(file_path, "rb") as f:

            data = pickle.load(f)


        index = data["index"]

        docs = data["docs"]


        # 6. CONVERT QUERY INTO VECTOR


        query_vector = encoder.encode(
            [query],
            convert_to_numpy=True
        )


        # 7. SEARCH FAISS


        D, I = index.search(
            query_vector,
            3
        )


        # 8. GET RELEVANT DOCUMENTS


        results = [
            docs[i]
            for i in I[0]
        ]


        # 9. CREATE CONTEXT


        context = "\n\n".join(
            doc.page_content
            for doc in results
        )
        # 10. SEND CONTEXT TO LLM

        response = chain.invoke({
            "context": context,
            "question": query
        })


        # --------------------------------------------------
        # ANSWER
        # --------------------------------------------------

        st.header("Answer")

        st.write(response.content)


        # --------------------------------------------------
        # SOURCES
        # --------------------------------------------------

        st.subheader("Sources:")

        sources = set()

        for doc in results:

            source = doc.metadata.get(
                "source",
                "Unknown source"
            )

            sources.add(source)


        for source in sources:

            st.write(source)

    else:

        st.warning(
            "Please process the URLs first."
        )
# Out:
# /tmp/ipykernel_6266/2288791181.py:11: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import UnstructuredURLLoader
# 2026-09-06 19:40:51.805 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.639
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-09-06 19:40:52.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.658 Session state does not function when running a script without `streamlit run`
# 2026-09-06 19:40:52.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-06 19:40:52.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_6266/2288791181.py in <cell line: 0>()
#      41 # --------------------------------------------------
#      42
# ---> 43 llm = ChatOpenAI(
#      44     model="gpt-5.5",
#      45     temperature=0,
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     134     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135         """"""  # noqa: D419  # Intentional blank docstring
# --> 136         super().__init__(*args, **kwargs)
#     137
#     138     @classmethod
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.13/dist-packages/langchain_openai/chat_models/base.py in validate_environment(self)
#    1439                 "api_key": async_api_key_value,
#    1440             }
# -> 1441             self.root_async_client = openai.AsyncOpenAI(
#    1442                 **client_params,
#    1443                 **async_specific,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.13/dist-packages/openai/_client.py in __init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     835             and self.admin_api_key is None
#     836         ):
# --> 837             raise OpenAIError(
#     838                 "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     839             )
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
from google.colab import userdata
import os

api_key = userdata.get("my_key")

os.environ["OPEN_API_KEY"] = api_key

print("API key loaded:", bool(api_key))
# Out:
# API key loaded: True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-5.5",
    temperature=0,
    max_tokens=500
)

response = llm.invoke("Say hello")

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipykernel_12125/3743504441.py in <cell line: 0>()
#       1 from langchain_openai import ChatOpenAI
#       2
# ----> 3 llm = ChatOpenAI(
#       4     model="gpt-5.5",
#       5     temperature=0,
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     134     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135         """"""  # noqa: D419  # Intentional blank docstring
# --> 136         super().__init__(*args, **kwargs)
#     137
#     138     @classmethod
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.13/dist-packages/langchain_openai/chat_models/base.py in validate_environment(self)
#    1463                 "api_key": async_api_key_value,
#    1464             }
# -> 1465             self.root_async_client = openai.AsyncOpenAI(
#    1466                 **client_params,
#    1467                 **async_specific,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.13/dist-packages/openai/_client.py in __init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     835             and self.admin_api_key is None
#     836         ):
# --> 837             raise OpenAIError(
#     838                 "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     839             )
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
# !pip install -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.13/dist-packages (4.4.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.23.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.6.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.13.5)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.58.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.10.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.0)

# %%
import os
import streamlit as st
import pickle
import time
import faiss

from sentence_transformers import SentenceTransformer

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import UnstructuredURLLoader
from langchain_core.prompts import ChatPromptTemplate

from dotenv import load_dotenv

load_dotenv()


# --------------------------------------------------
# STREAMLIT UI
# --------------------------------------------------

st.title("RockyBot: News Research Tool 📈")
st.sidebar.title("News Article URLs")

urls = []

for i in range(3):
    url = st.sidebar.text_input(f"URL {i+1}")
    urls.append(url)

process_url_clicked = st.sidebar.button("Process URLs")

file_path = "faiss_store.pkl"

main_placeholder = st.empty()


# --------------------------------------------------
# LLM
# --------------------------------------------------

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=500
)


# --------------------------------------------------
# SENTENCE TRANSFORMER
# --------------------------------------------------

encoder = SentenceTransformer("all-MiniLM-L6-v2")


# --------------------------------------------------
# PROMPT
# --------------------------------------------------

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        """You are a helpful news research assistant.

Answer the question using only the provided context.

If the answer cannot be found in the context,
say that you don't know.

Context:
{context}
"""
    ),
    ("human", "{question}")
])


chain = prompt | llm


# --------------------------------------------------
# PROCESS URLS
# --------------------------------------------------

if process_url_clicked:

    # Remove empty URLs
    urls = [url for url in urls if url.strip()]

    if not urls:
        st.error("Please enter at least one URL.")
        st.stop()


    # --------------------------------------------------
    # 1. LOAD DATA
    # --------------------------------------------------

    main_placeholder.text(
        "Data Loading...Started...✅"
    )

    loader = UnstructuredURLLoader(urls=urls)

    data = loader.load()

    st.write("Documents loaded:", len(data))


    # --------------------------------------------------
    # 2. TEXT SPLITTING
    # --------------------------------------------------

    main_placeholder.text(
        "Text Splitting...Started...✅"
    )

    text_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n", ".", ","],
        chunk_size=1000,
        chunk_overlap=100
    )

    docs = text_splitter.split_documents(data)

    st.write("Number of chunks:", len(docs))


    # --------------------------------------------------
    # 3. CREATE EMBEDDINGS
    # --------------------------------------------------

    main_placeholder.text(
        "Creating Embeddings...Started...✅"
    )

    texts = [
        doc.page_content
        for doc in docs
    ]

    vectors = encoder.encode(
        texts,
        convert_to_numpy=True
    )

    st.write("Embedding shape:", vectors.shape)


    # --------------------------------------------------
    # 4. CREATE FAISS INDEX
    # --------------------------------------------------

    main_placeholder.text(
        "Building FAISS Index...Started...✅"
    )

    dimension = vectors.shape[1]

    index = faiss.IndexFlatL2(dimension)

    index.add(vectors)

    st.write("Vectors stored in FAISS:", index.ntotal)


    # --------------------------------------------------
    # 5. SAVE FAISS + DOCUMENTS
    # --------------------------------------------------

    with open(file_path, "wb") as f:

        pickle.dump(
            {
                "index": index,
                "docs": docs
            },
            f
        )


    main_placeholder.text(
        "Processing Complete! ✅"
    )

    time.sleep(1)

    main_placeholder.empty()


# --------------------------------------------------
# QUESTION
# --------------------------------------------------

query = st.text_input("Question:")


if query:

    if os.path.exists(file_path):


        # LOAD FAISS + DOCUMENTS


        with open(file_path, "rb") as f:

            data = pickle.load(f)


        index = data["index"]

        docs = data["docs"]


        # 6. CONVERT QUERY INTO VECTOR


        query_vector = encoder.encode(
            [query],
            convert_to_numpy=True
        )


        # 7. SEARCH FAISS


        D, I = index.search(
            query_vector,
            3
        )


        # 8. GET RELEVANT DOCUMENTS


        results = [
            docs[i]
            for i in I[0]
        ]


        # 9. CREATE CONTEXT


        context = "\n\n".join(
            doc.page_content
            for doc in results
        )
        # 10. SEND CONTEXT TO LLM

        response = chain.invoke({
            "context": context,
            "question": query
        })


        # --------------------------------------------------
        # ANSWER
        # --------------------------------------------------

        st.header("Answer")

        st.write(response.content)


        # --------------------------------------------------
        # SOURCES
        # --------------------------------------------------

        st.subheader("Sources:")

        sources = set()

        for doc in results:

            source = doc.metadata.get(
                "source",
                "Unknown source"
            )

            sources.add(source)


        for source in sources:

            st.write(source)

    else:

        st.warning(
            "Please process the URLs first."
        )
# Out:
# /tmp/ipykernel_12125/3297128498.py:11: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import UnstructuredURLLoader
# 2026-09-12 07:43:25.159 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.472
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-09-12 07:43:25.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.503 Session state does not function when running a script without `streamlit run`
# 2026-09-12 07:43:25.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-12 07:43:25.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipykernel_12125/3297128498.py in <cell line: 0>()
#      41 # --------------------------------------------------
#      42
# ---> 43 llm = ChatGoogleGenerativeAI(
#      44     model="gemini-2.5-flash",
#      45     temperature=0,
#
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py in __init__(self, **kwargs)
#    3306                     f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    3307                 )
# -> 3308         super().__init__(**kwargs)
#    3309
#    3310     model_config = ConfigDict(
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     134     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135         """"""  # noqa: D419  # Intentional blank docstring
# --> 136         super().__init__(*args, **kwargs)
#     137
#     138     @classmethod
#
# /usr/local/lib/python3.13/dist-packages/pydantic/main.py in __init__(self, **data)
#     261         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262         __tracebackhide__ = True
# --> 263         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264         if self is not validated_self:
#     265             warnings.warn(
#
# ValidationError: 1 validation error for ChatGoogleGenerativeAI
#   Value error, API key required for Gemini Developer API. Provide api_key parameter or set GOOGLE_API_KEY/GEMINI_API_KEY environment variable. [type=value_error, input_value={'model': 'gemini-2.5-fla...': {}, 'base_url': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error

# %%
# !pip install -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.13/dist-packages (4.4.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.23.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.6.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.13.5)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.58.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.10.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.0)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=0
)

response = llm.invoke(
    "Explain FAISS in one sentence."
)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipykernel_12125/31092696.py in <cell line: 0>()
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       2
# ----> 3 llm = ChatGoogleGenerativeAI(
#       4     model="gemini-3.6-flash",
#       5     temperature=0
#
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py in __init__(self, **kwargs)
#    3306                     f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    3307                 )
# -> 3308         super().__init__(**kwargs)
#    3309
#    3310     model_config = ConfigDict(
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     134     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135         """"""  # noqa: D419  # Intentional blank docstring
# --> 136         super().__init__(*args, **kwargs)
#     137
#     138     @classmethod
#
# /usr/local/lib/python3.13/dist-packages/pydantic/main.py in __init__(self, **data)
#     261         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262         __tracebackhide__ = True
# --> 263         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264         if self is not validated_self:
#     265             warnings.warn(
#
# ValidationError: 1 validation error for ChatGoogleGenerativeAI
#   Value error, API key required for Gemini Developer API. Provide api_key parameter or set GOOGLE_API_KEY/GEMINI_API_KEY environment variable. [type=value_error, input_value={'model': 'gemini-3.6-fla...': {}, 'base_url': None}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error

# %%
# %pip install -q streamlit pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 46.4 MB/s eta 0:00:00

# %%
# %pip install -q faiss-cpu sentence-transformers langchain-text-splitters langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 553.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 40.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 10.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.

# %%
# !streamlit run app.py &>/content/streamlit.log &

# %%
# !cat /content/streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data  streamlit.log

# %%
# %%writefile app.py

import streamlit as st

st.title("RockyBot: News Research Tool 📈")

st.write("Streamlit is working!")
# Out:
# Writing app.py

# %%
# !ls -l
# Out:
# total 12
# -rw-r--r-- 1 root root  106 Sep  7 14:19 app.py
# drwxr-xr-x 1 root root 4096 Aug 24 13:21 sample_data
# -rw-r--r-- 1 root root  138 Sep  7 14:17 streamlit.log

# %%
# !cat /content/streamlit.log
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-09-07 14:20:16.009 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.185.4.189:8501

# %%
# !pip install -q pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3J0HRvPX34W6HIAHwtnDEOXeDOI_62aSr5q22pvewohu7N9wM")

public_url = ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://dart-clean-glutton.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !streamlit run app.py > /content/streamlit.log 2>&1 &

# %%
# %pip install -q langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.6 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

print("UnstructuredURLLoader imported successfully!")
# Out:
# UnstructuredURLLoader imported successfully!

# %%
from google.colab import userdata
import os

api_key = userdata.get("my_key")

os.environ["OPEN_API_KEY"] = api_key

print("API key loaded:", bool(api_key))
# Out:
# API key loaded: True

# %%
# %pip install -q unstructured
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.9/109.9 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 44.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.6/169.6 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.3/394.3 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 55.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 6.0 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
# %pip install -q unstructured beautifulsoup4 requests

# %%
import unstructured

print("unstructured installed successfully")
# Out:
# unstructured installed successfully

# %%
from google.colab import userdata
import os

gemini_key = userdata.get("my_key")

os.environ["GOOGLE_API_KEY"] = gemini_key

print(
    "Gemini key loaded:",
    bool(os.environ.get("GOOGLE_API_KEY"))
)
# Out:
# Gemini key loaded: True

# %%
# %%writefile app.py

import os
import pickle
import faiss
import streamlit as st

from sentence_transformers import SentenceTransformer

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import UnstructuredURLLoader
from langchain_core.prompts import ChatPromptTemplate

from dotenv import load_dotenv

load_dotenv()


# ============================================================
# PAGE
# ============================================================

st.set_page_config(
    page_title="RockyBot",
    page_icon="📈"
)

st.title("RockyBot: News Research Tool 📈")


# ============================================================
# SIDEBAR - URL INPUT
# ============================================================

st.sidebar.title("News Article URLs")

urls = []

for i in range(3):

    url = st.sidebar.text_input(
        f"URL {i + 1}"
    )

    urls.append(url)


process_url_clicked = st.sidebar.button(
    "Process URLs"
)


# ============================================================
# FILE
# ============================================================

file_path = "faiss_store.pkl"


# ============================================================
# STATUS AREA
# ============================================================

main_placeholder = st.empty()


# ============================================================
# SENTENCE TRANSFORMER
# ============================================================

@st.cache_resource
def load_encoder():

    return SentenceTransformer(
        "all-MiniLM-L6-v2"
    )


encoder = load_encoder()


# ============================================================
# GEMINI
# ============================================================

@st.cache_resource
def load_llm():

    return ChatGoogleGenerativeAI(
        model="gemini-3.6-flash",
        max_tokens=500
    )


llm = load_llm()


# ============================================================
# PROMPT
# ============================================================

prompt = ChatPromptTemplate.from_messages([

    (
        "system",
        """
You are a helpful news research assistant.

Answer the question using ONLY the provided context.

If the answer cannot be found in the context,
say that you don't know.

Context:

{context}
"""
    ),

    (
        "human",
        "{question}"
    )
])


chain = prompt | llm


# ============================================================
# PROCESS URLS
# ============================================================

if process_url_clicked:

    # Remove empty URLs

    urls = [
        url for url in urls
        if url.strip()
    ]


    if not urls:

        st.sidebar.error(
            "Please enter at least one URL."
        )

        st.stop()


    # ========================================================
    # 1. LOAD DATA
    # ========================================================

    main_placeholder.text(
        "1️⃣ Loading data..."
    )

    loader = UnstructuredURLLoader(
        urls=urls
    )

    data = loader.load()

    st.success(
        f"Documents loaded: {len(data)}"
    )


    # ========================================================
    # 2. TEXT SPLITTING
    # ========================================================

    main_placeholder.text(
        "2️⃣ Splitting text into chunks..."
    )

    text_splitter = RecursiveCharacterTextSplitter(

        separators=[
            "\n\n",
            "\n",
            ".",
            ",",
            " "
        ],

        chunk_size=200,

        chunk_overlap=0
    )


    chunks = text_splitter.split_documents(
        data
    )


    if not chunks:

        st.error(
            "No text chunks were created from the URLs."
        )

        st.stop()


    st.success(
        f"Chunks created: {len(chunks)}"
    )


    # ========================================================
    # SHOW FIRST CHUNK
    # ========================================================

    with st.expander("View first chunk"):

        st.write(
            chunks[0].page_content
        )

        st.write(
            "Characters:",
            len(chunks[0].page_content)
        )


    # ========================================================
    # 3. CREATE EMBEDDINGS
    # ========================================================

    main_placeholder.text(
        "3️⃣ Creating embeddings..."
    )


    texts = [
        chunk.page_content
        for chunk in chunks
    ]


    vectors = encoder.encode(

        texts,

        convert_to_numpy=True
    )


    st.write(
        "Embedding shape:",
        vectors.shape
    )


    # ========================================================
    # 4. CREATE FAISS INDEX
    # ========================================================

    main_placeholder.text(
        "4️⃣ Building FAISS index..."
    )


    dimension = vectors.shape[1]


    index = faiss.IndexFlatL2(
        dimension
    )


    index.add(
        vectors
    )


    st.success(
        f"FAISS vectors stored: {index.ntotal}"
    )


    # ========================================================
    # 5. SAVE FAISS + DOCUMENTS
    # ========================================================

    with open(
        file_path,
        "wb"
    ) as f:

        pickle.dump(

            {
                "index": index,
                "docs": chunks
            },

            f
        )


    main_placeholder.success(
        "Processing complete! ✅"
    )


# ============================================================
# QUESTION
# ============================================================

st.divider()

st.header("Ask a Question")

query = st.text_input(
    "Question:",
    placeholder="Example: What happened to Tata Motors?"
)


# ============================================================
# RETRIEVAL
# ============================================================

if query:

    # ========================================================
    # CHECK FAISS FILE
    # ========================================================

    if not os.path.exists(
        file_path
    ):

        st.warning(
            "Please process the URLs first."
        )

        st.stop()


    # ========================================================
    # LOAD FAISS + DOCUMENTS
    # ========================================================

    with open(
        file_path,
        "rb"
    ) as f:

        stored_data = pickle.load(f)


    index = stored_data["index"]

    chunks = stored_data["docs"]


    # ========================================================
    # QUERY EMBEDDING
    # ========================================================

    query_vector = encoder.encode(

        [query],

        convert_to_numpy=True
    )


    # ========================================================
    # FAISS SEARCH
    # ========================================================

    D, I = index.search(

        query_vector,

        3
    )


    # ========================================================
    # RETRIEVE TOP 3 CHUNKS
    # ========================================================

    results = [

        chunks[i]

        for i in I[0]

        if i != -1
    ]


    # ========================================================
    # SHOW RETRIEVED CHUNKS
    # ========================================================

    with st.expander(
        "View retrieved chunks"
    ):

        for i, result in zip(
            I[0],
            results
        ):

            st.write(
                f"Chunk index: {i}"
            )

            st.write(
                result.page_content
            )

            st.write("---")


    # ========================================================
    # CREATE CONTEXT
    # ========================================================

    context = "\n\n".join(

        result.page_content

        for result in results
    )


    # ========================================================
    # SEND CONTEXT + QUESTION TO GEMINI
    # ========================================================

    with st.spinner(
        "Generating answer..."
    ):

        response = chain.invoke({

            "context": context,

            "question": query

        })


    # ========================================================
    # EXTRACT ANSWER
    # ========================================================

    content = response.content


    if isinstance(
        content,
        list
    ):

        answer = "\n".join(

            block.get(
                "text",
                ""
            )

            for block in content

            if isinstance(
                block,
                dict
            )

            and block.get(
                "type"
            ) == "text"

        )

    else:

        answer = content


    # ========================================================
    # DISPLAY ANSWER
    # ========================================================

    st.header(
        "Answer"
    )

    st.write(
        answer
    )


    # ========================================================
    # DISPLAY SOURCES
    # ========================================================

    st.subheader(
        "Sources"
    )


    sources = set()


    for result in results:

        source = result.metadata.get(

            "source",

            "Unknown source"

        )

        sources.add(
            source
        )


    for source in sources:

        st.write(
            source
        )
# Out:
# Overwriting app.py

# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py > /content/streamlit.log 2>&1 &
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-09-12T07:17:15+0000 lvl=warn msg="failed to open private leg" id=cc4ad01c1f7c privaddr=localhost:8501 err="dial tcp [::1]:8501: connect: connection refused"

# %%
from pyngrok import ngrok


ngrok.set_auth_token("3J0HRvPX34W6HIAHwtnDEOXeDOI_62aSr5q22pvewohu7N9wM")

public_url = ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://dart-clean-glutton.ngrok-free.dev" -> "http://localhost:8501"

# %%
from google.colab import userdata
import os

os.environ["GOOGLE_API_KEY"] = userdata.get("my_key")

print("Gemini key loaded:", bool(os.environ.get("GOOGLE_API_KEY")))
# Out:
# Gemini key loaded: True

# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py > /content/streamlit.log 2>&1 &

# %%
from pyngrok import ngrok

# See existing tunnels
print(ngrok.get_tunnels())
# Out:
# [<NgrokTunnel: "https://dart-clean-glutton.ngrok-free.dev" -> "http://localhost:8501">]

# %%
ngrok.kill()

# %%
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://dart-clean-glutton.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !pkill -f streamlit
# !streamlit run app.py > /content/streamlit.log 2>&1 &

# %%
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://dart-clean-glutton.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !ps aux | grep streamlit
# Out:
# root        3985  0.0  0.0   7340  3508 ?        S    07:12   0:00 /bin/bash -c ps aux | grep streamlit
# root        3987  0.0  0.0   6544  2292 ?        S    07:12   0:00 grep streamlit

# %%
# !curl -I http://127.0.0.1:8501
# Out:
# curl: (7) Failed to connect to 127.0.0.1 port 8501 after 0 ms: Couldn't connect to server
